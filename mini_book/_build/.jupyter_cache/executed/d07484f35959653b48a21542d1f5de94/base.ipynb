# %%
from matplotlib import rcParams, cycler
import matplotlib.pyplot as plt
import numpy as np
plt.ion()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 10
data = [np.logspace(0, 1, 100) + np.random.randn(100) + ii for ii in range(N)]
data = np.array(data).T
cmap = plt.cm.coolwarm
rcParams['axes.prop_cycle'] = cycler(color=cmap(np.linspace(0, 1, N)))


from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color=cmap(0.), lw=4),
                Line2D([0], [0], color=cmap(.5), lw=4),
                Line2D([0], [0], color=cmap(1.), lw=4)]

fig, ax = plt.subplots(figsize=(10, 5))
lines = ax.plot(data)
ax.legend(custom_lines, ['Cold', 'Medium', 'Hot'])

# %%
print(val_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(val_a)
#
# NameError: name 'val_a' is not defined

# %%
import numpy as np
import pandas as pd

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
            axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan

def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df.style.\
    applymap(color_negative_red).\
    apply(highlight_max).\
    set_table_attributes('style="font-size: 10px"')
# Out:
# <style type="text/css">
# #T_aafdb_row0_col0, #T_aafdb_row0_col1, #T_aafdb_row0_col2, #T_aafdb_row1_col0, #T_aafdb_row1_col3, #T_aafdb_row1_col4, #T_aafdb_row2_col0, #T_aafdb_row2_col2, #T_aafdb_row2_col3, #T_aafdb_row3_col0, #T_aafdb_row3_col1, #T_aafdb_row3_col2, #T_aafdb_row3_col3, #T_aafdb_row3_col4, #T_aafdb_row4_col0, #T_aafdb_row4_col1, #T_aafdb_row4_col2, #T_aafdb_row4_col3, #T_aafdb_row4_col4, #T_aafdb_row5_col0, #T_aafdb_row5_col2, #T_aafdb_row5_col3, #T_aafdb_row6_col0, #T_aafdb_row6_col1, #T_aafdb_row6_col4, #T_aafdb_row7_col0, #T_aafdb_row7_col1, #T_aafdb_row7_col2, #T_aafdb_row7_col4, #T_aafdb_row8_col0, #T_aafdb_row9_col2, #T_aafdb_row9_col4 {
#   color: black;
# }
# #T_aafdb_row0_col3, #T_aafdb_row0_col4, #T_aafdb_row1_col1, #T_aafdb_row1_col2, #T_aafdb_row2_col1, #T_aafdb_row5_col1, #T_aafdb_row5_col4, #T_aafdb_row6_col3, #T_aafdb_row7_col3, #T_aafdb_row8_col2, #T_aafdb_row8_col4, #T_aafdb_row9_col1, #T_aafdb_row9_col3 {
#   color: red;
# }
# #T_aafdb_row2_col4, #T_aafdb_row6_col2, #T_aafdb_row8_col1, #T_aafdb_row8_col3, #T_aafdb_row9_col0 {
#   color: black;
#   background-color: yellow;
# }
# </style>
# <table id="T_aafdb" style="font-size: 10px">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aafdb_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_aafdb_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_aafdb_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_aafdb_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_aafdb_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aafdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aafdb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_aafdb_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_aafdb_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_aafdb_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_aafdb_row0_col4" class="data row0 col4" >-0.990810</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aafdb_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_aafdb_row1_col1" class="data row1 col1" >-1.070816</td>
#       <td id="T_aafdb_row1_col2" class="data row1 col2" >-1.438713</td>
#       <td id="T_aafdb_row1_col3" class="data row1 col3" >0.564417</td>
#       <td id="T_aafdb_row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aafdb_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_aafdb_row2_col1" class="data row2 col1" >-1.626404</td>
#       <td id="T_aafdb_row2_col2" class="data row2 col2" >0.219565</td>
#       <td id="T_aafdb_row2_col3" class="data row2 col3" >0.678805</td>
#       <td id="T_aafdb_row2_col4" class="data row2 col4" >1.889273</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aafdb_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_aafdb_row3_col1" class="data row3 col1" >0.961538</td>
#       <td id="T_aafdb_row3_col2" class="data row3 col2" >0.104011</td>
#       <td id="T_aafdb_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_aafdb_row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aafdb_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_aafdb_row4_col1" class="data row4 col1" >1.453425</td>
#       <td id="T_aafdb_row4_col2" class="data row4 col2" >1.057737</td>
#       <td id="T_aafdb_row4_col3" class="data row4 col3" >0.165562</td>
#       <td id="T_aafdb_row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aafdb_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_aafdb_row5_col1" class="data row5 col1" >-1.336936</td>
#       <td id="T_aafdb_row5_col2" class="data row5 col2" >0.562861</td>
#       <td id="T_aafdb_row5_col3" class="data row5 col3" >1.392855</td>
#       <td id="T_aafdb_row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aafdb_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_aafdb_row6_col1" class="data row6 col1" >0.121668</td>
#       <td id="T_aafdb_row6_col2" class="data row6 col2" >1.207603</td>
#       <td id="T_aafdb_row6_col3" class="data row6 col3" >-0.002040</td>
#       <td id="T_aafdb_row6_col4" class="data row6 col4" >1.627796</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aafdb_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_aafdb_row7_col1" class="data row7 col1" >0.354493</td>
#       <td id="T_aafdb_row7_col2" class="data row7 col2" >1.037528</td>
#       <td id="T_aafdb_row7_col3" class="data row7 col3" >-0.385684</td>
#       <td id="T_aafdb_row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aafdb_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_aafdb_row8_col1" class="data row8 col1" >1.686583</td>
#       <td id="T_aafdb_row8_col2" class="data row8 col2" >-1.325963</td>
#       <td id="T_aafdb_row8_col3" class="data row8 col3" >1.428984</td>
#       <td id="T_aafdb_row8_col4" class="data row8 col4" >-2.089354</td>
#     </tr>
#     <tr>
#       <th id="T_aafdb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aafdb_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_aafdb_row9_col1" class="data row9 col1" >-0.129820</td>
#       <td id="T_aafdb_row9_col2" class="data row9 col2" >0.631523</td>
#       <td id="T_aafdb_row9_col3" class="data row9 col3" >-0.586538</td>
#       <td id="T_aafdb_row9_col4" class="data row9 col4" >0.290720</td>
#     </tr>
#   </tbody>
# </table>

# %%
for ii in range(40):
    print(f"this is output line {ii}")
# Out:
# this is output line 0
# this is output line 1
# this is output line 2
# this is output line 3
# this is output line 4
# this is output line 5
# this is output line 6
# this is output line 7
# this is output line 8
# this is output line 9
# this is output line 10
# this is output line 11
# this is output line 12
# this is output line 13
# this is output line 14
# this is output line 15
# this is output line 16
# this is output line 17
# this is output line 18
# this is output line 19
# this is output line 20
# this is output line 21
# this is output line 22
# this is output line 23
# this is output line 24
# this is output line 25
# this is output line 26
# this is output line 27
# this is output line 28
# this is output line 29
# this is output line 30
# this is output line 31
# this is output line 32
# this is output line 33
# this is output line 34
# this is output line 35
# this is output line 36
# this is output line 37
# this is output line 38
# this is output line 39

# %%
text = " XYZ "
formatstring = "\x1b[{}m" + text + "\x1b[m"

print(
    " " * 6
    + " " * len(text)
    + "".join("{:^{}}".format(bg, len(text)) for bg in range(40, 48))
)
for fg in range(30, 38):
    for bold in False, True:
        fg_code = ("1;" if bold else "") + str(fg)
        print(
            " {:>4} ".format(fg_code)
            + formatstring.format(fg_code)
            + "".join(
                formatstring.format(fg_code + ";" + str(bg)) for bg in range(40, 48)
            )
        )
# Out:
#             40   41   42   43   44   45   46   47
#    30  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;30  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    31  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;31  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    32  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;32  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    33  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;33  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    34  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;34  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    35  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;35  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    36  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;36  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#    37  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ
#  1;37  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ  XYZ

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %%
from myst_nb import glue

# %%
my_variable = "here is some text!"
glue("cool_text", my_variable,  display=False)

# %%
# Simulate some data and bootstrap the mean of the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_points = 10000
n_boots = 1000
mean, sd = (3, .2)
data = sd*np.random.randn(n_points) + mean
bootstrap_indices = np.random.randint(0, n_points, n_points*n_boots).reshape((n_boots, n_points))

# Calculate the mean of a bunch of random samples
means = data[bootstrap_indices].mean(0)
# Calculate the 95% confidence interval for the mean
clo, chi = np.percentile(means, [2.5, 97.5])

# Visualize the histogram with the intervals
fig, ax = plt.subplots()
ax.hist(means)
for ln in [clo, chi]:
    ax.axvline(ln, ls='--', c='r')
ax.set_title("Bootstrap distribution and 95% CI")

# And a wider figure to show a timeseries
fig2, ax = plt.subplots(figsize=(6, 2))
ax.plot(np.sort(means), lw=3, c='r')
ax.set_axis_off()


# Store the values in our notebook

glue("boot_mean", means.mean(), display=False) # numero
glue("boot_clo", clo, display=False)           # numero
glue("boot_chi", chi, display=False)           # numero

glue("boot_fig", fig, display=False)           # Plot
glue("sorted_means_fig", fig2, display=False)  # Plot

# Dataframes

bootstrap_subsets = data[bootstrap_indices][:3, :5].T
df = pd.DataFrame(bootstrap_subsets, columns=["first", "second", "third"])
display(df)

glue("df_tbl", df, display=False)
# Out:
#       first    second     third
# 0  3.387264  2.657882  2.811197
# 1  3.162860  3.002507  3.108126
# 2  3.255507  2.965464  2.448430
# 3  3.178746  2.988489  2.862812
# 4  3.068833  2.706753  3.203644

# %%
import sympy as sym
f = sym.Function('f')
y = sym.Function('y')
n = sym.symbols(r'\alpha')
f = y(n)-2*y(n-1/sym.pi)-5*y(n-2)
glue("sym_eq", sym.rsolve(f,y(n),[1,4]) ,display=False)
